# %%
# !git clone https://github.com/open-edge-platform/anomalib.git
# %cd anomalib
# !pip install -e .[full]
# Out:
# Cloning into 'anomalib'...
# remote: Enumerating objects: 12496, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 12496 (delta 138), reused 100 (delta 99), pack-reused 12222 (from 5)
# Receiving objects: 100% (12496/12496), 62.44 MiB | 15.26 MiB/s, done.
# Resolving deltas: 100% (6962/6962), done.
# /content/anomalib
# Obtaining file:///content/anomalib
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !ls -R /content/drive/MyDrive/wood_dataset
# Out:
# /content/drive/MyDrive/wood_dataset:
# carpet	hazelnut  metal_nut  pill   tile	transistor  wood_orjinal
# grid	leather   MVTecAD    screw  toothbrush	wood	    zipper
#
# /content/drive/MyDrive/wood_dataset/carpet:
# ground_truth  license.txt  readme.txt  test  train
#
# /content/drive/MyDrive/wood_dataset/carpet/ground_truth:
# color  cut  hole  metal_contamination  thread
#
# /content/drive/MyDrive/wood_dataset/carpet/ground_truth/color:
# 000_mask.png  004_mask.png  008_mask.png  012_mask.png	016_mask.png
# 001_mask.png  005_mask.png  009_mask.png  013_mask.png	017_mask.png
# 002_mask.png  006_mask.png  010_mask.png  014_mask.png	018_mask.png
# 003_mask.png  007_mask.png  011_mask.png  015_mask.png
#
# /content/drive/MyDrive/wood_dataset/carpet/ground_truth/cut:
# 000_mask.png  004_mask.png  008_mask.png  012_mask.png	016_mask.png
# 001_mask.png  005_mask.png  009_mask.png  013_mask.png
# 002_mask.png  006_mask.png  010_mask.png  014_mask.png
# ...

# %%
from anomalib.data import MVTecAD
from anomalib.models import Patchcore
from anomalib.engine import Engine

datamodule = MVTecAD(
    category="wood",
    root="/content/drive/MyDrive/wood_dataset"
    )
model = Patchcore()
engine = Engine()

engine.fit(datamodule=datamodule, model=model)
# Out:
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# ...

# %%
predictions = engine.predict(
    datamodule=datamodule,
    model=model,
    ckpt_path="/content/results/Patchcore/MVTecAD/wood/v2/weights/lightning/model.ckpt",
)
# Out:
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO:lightning_fabric.utilities.rank_zero:Restoring states from the checkpoint path at /content/results/Patchcore/MVTecAD/wood/v2/weights/lightning/model.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning_fabric.utilities.rank_zero:Loaded model weights from the checkpoint at /content/results/Patchcore/MVTecAD/wood/v2/weights/lightning/model.ckpt
# Predicting: |          | 0/? [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-5ce0eee7f7e1> in <cell line: 0>()
# ----> 1 predictions = engine.predict(
# ...

# %%
from anomalib.data import MVTecAD
from anomalib.models import Patchcore
from anomalib.engine import Engine

datamodule = MVTecAD(category="wood", root="/content/drive/MyDrive/wood_dataset/MVTecAD/wood")
model = Patchcore()
engine = Engine()

engine.fit(datamodule=datamodule, model=model)
# Out:
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:lightning_fabric.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name           | Type           | Params | Mode
# ----------------------------------------------------------
# 0 | pre_processor  | PreProcessor   | 0      | train
# 1 | post_processor | PostProcessor  | 0      | train
# 2 | evaluator      | Evaluator      | 0      | train
# 3 | model          | PatchcoreModel | 24.9 M | train
# ----------------------------------------------------------
# 24.9 M    Trainable params
# ...
